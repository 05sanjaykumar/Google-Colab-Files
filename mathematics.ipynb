# %%
import numpy as np

# Define a vector
v = np.array([5, 12])
print("Vector v:", v)

# Magnitude (length) of the vector
magnitude = np.linalg.norm(v)
print("Magnitude:", magnitude)

# Normalize the vector (convert to unit vector)
unit_vector = v / magnitude
print("Unit Vector:", unit_vector)
# Out:
# Vector v: [3 4]
# Magnitude: 5.0
# Unit Vector: [0.6 0.8]

# %%
import numpy as np
A = np.array([[1, 2],
              [3, 4]])

# Transpose (flips rows and columns)
A_T = A.T
print("Transpose:\n", A_T)
# Out:
# Transpose:
#  [[1 3]
#  [2 4]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_olivetti_faces
from sklearn.decomposition import PCA

# Load the Olivetti faces dataset
faces = fetch_olivetti_faces(shuffle=True, random_state=42)
images = faces.images

# Flatten the images into vectors
n_samples, height, width = images.shape
X = images.reshape(n_samples, height * width)

# Number of principal components to keep
n_components = 100

# Perform PCA
pca = PCA(n_components=n_components)
X_reduced = pca.fit_transform(X)

# Reconstruct images from the reduced representation
X_reconstructed = pca.inverse_transform(X_reduced)
images_reconstructed = X_reconstructed.reshape(n_samples, height, width)

# Display original and reconstructed images
def plot_gallery(images, n_row=3, n_col=6):
    plt.figure(figsize=(1.5 * n_col, 1.7 * n_row))
    plt.subplots_adjust(bottom=0, left=.01, right=.99, top=.90, hspace=.35)
    for i in range(n_row * n_col):
        plt.subplot(n_row, n_col, i + 1)
        plt.imshow(images[i], cmap=plt.cm.gray, interpolation='nearest')
        plt.xticks(())
        plt.yticks(())

plot_gallery(images[:18])
plt.suptitle('Original Images')
plt.show()

plot_gallery(images_reconstructed[:18])
plt.suptitle('Reconstructed Images ({} Components)'.format(n_components))
plt.show()

# Display the eigenfaces
eigenfaces = pca.components_.reshape((n_components, height, width))
plot_gallery(eigenfaces[:18])
plt.suptitle('Eigenfaces')
plt.show()

#Show the explained variance ratio
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title("Explained Variance Ratio")
plt.show()

print(f"Explained Variance with {n_components} components: {np.sum(pca.explained_variance_ratio_)}")
# Out:
# downloading Olivetti faces from https://ndownloader.figshare.com/files/5976027 to /root/scikit_learn_data
# Explained Variance with 100 components: 0.9350258708000183

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris

iris = load_iris()
X = iris.data
Y = iris.target

print(X)
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.  1.4 0.1]
#  [4.3 3.  1.1 0.1]
#  [5.8 4.  1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.  0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.  3.  1.6 0.2]
#  [5.  3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.2]
#  [5.  3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.6 1.4 0.1]
#  [4.4 3.  1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.  3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.  3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.  1.4 0.3]
#  [5.1 3.8 1.6 0.2]
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris

# Load the Iris dataset (a classic dataset for PCA examples)
iris = load_iris()
X = iris.data
y = iris.target
target_names = iris.target_names

# Perform PCA to reduce to 2 dimensions for visualization
pca = PCA(n_components=2)
X_reduced = pca.fit_transform(X)
print('reduced pca \n',X_reduced)

# Visualize the reduced data
plt.figure(figsize=(8, 6))
for target, color, label in zip(np.unique(y), ['r', 'g', 'b'], target_names):
    plt.scatter(X_reduced[y == target, 0], X_reduced[y == target, 1], c=color, label=label)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Iris Dataset (2 Components)')
plt.legend()
plt.grid(True)
plt.show()

# Explained variance ratio
print("Explained variance ratio (first two components):", pca.explained_variance_ratio_)

# How to access principal components:
print("Principal components (eigenvectors):\n", pca.components_)

# Original Data shape and reduced data shape
print(f"Original data shape : {X.shape}")
print(f"Reduced data shape: {X_reduced.shape}")
# Out:
# reduced pca
#  [[-2.68412563  0.31939725]
#  [-2.71414169 -0.17700123]
#  [-2.88899057 -0.14494943]
#  [-2.74534286 -0.31829898]
#  [-2.72871654  0.32675451]
#  [-2.28085963  0.74133045]
#  [-2.82053775 -0.08946138]
#  [-2.62614497  0.16338496]
#  [-2.88638273 -0.57831175]
#  [-2.6727558  -0.11377425]
#  [-2.50694709  0.6450689 ]
#  [-2.61275523  0.01472994]
#  [-2.78610927 -0.235112  ]
#  [-3.22380374 -0.51139459]
#  [-2.64475039  1.17876464]
#  [-2.38603903  1.33806233]
#  [-2.62352788  0.81067951]
#  [-2.64829671  0.31184914]
#  [-2.19982032  0.87283904]
#  [-2.5879864   0.51356031]
#  [-2.31025622  0.39134594]
#  [-2.54370523  0.43299606]
#  [-3.21593942  0.13346807]
#  [-2.30273318  0.09870885]
#  [-2.35575405 -0.03728186]
#  [-2.50666891 -0.14601688]
#  [-2.46882007  0.13095149]
#  [-2.56231991  0.36771886]
#  [-2.63953472  0.31203998]
#  [-2.63198939 -0.19696122]
#  [-2.58739848 -0.20431849]
#  [-2.4099325   0.41092426]
#  [-2.64886233  0.81336382]
# ...

# %%
A = np.array([[1, 2],
              [3, 4]])


# Matrix multiplication
B = np.array([[5, 6],
              [7, 8]])
C = np.dot(A, B)  # OR A @ B
print("Matrix Multiplication:\n", C)
# Out:
# Matrix Multiplication:
#  [[19 22]
#  [43 50]]

# %%
import matplotlib.pyplot as plt

v1 = np.array([2, 3])
v2 = np.array([-1, 2])

plt.quiver(0,0,v1[0],v1[1],angles='xy', scale_units='xy', scale=1, color='r', label="v1")
plt.quiver(0, 0, v2[0], v2[1], angles='xy', scale_units='xy', scale=1, color='b', label="v2")

plt.xlim(-1, 5)
plt.ylim(-5, 5)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid()
plt.legend()
plt.show()

# %%
# Define a square matrix
A = np.array([[1, 2],
              [3, 4]])

# Compute eigenvalues & eigenvectors
eigenvalues, eigenvectors = np.linalg.eig(A)

print("Eigenvalues:\n", eigenvalues)
print("Eigenvectors:\n", eigenvectors)
# Out:
# Eigenvalues:
#  [-0.37228132  5.37228132]
# Eigenvectors:
#  [[-0.82456484 -0.41597356]
#  [ 0.56576746 -0.90937671]]
